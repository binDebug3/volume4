# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib notebook
# Out:
# Traceback (most recent call last):
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 241, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\_pylab_helpers.py", line 58, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 241, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\_pylab_helpers.py", line 58, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 241, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\_pylab_helpers.py", line 58, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 241, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\_pylab_helpers.py", line 58, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 241, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\_pylab_helpers.py", line 58, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ## Problem 1
#
# Use the FuncAnimation class to animate the function $y = sin(x + \frac{t}{10})$ where $x \in [0, 2\pi]$, and t ranges from 0 to 100 seconds.
# Save your animation to a file and embed the created file.

# %%
x = np.linspace(0,2*np.pi,100)
t = np.arange(100)
y = lambda x,t: np.sin(x+t/10)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlim(-0.1 ,2*np.pi + 0.1)
ax.set_ylim(-1.1,1.1)
particle, = plt.plot([],[], marker='o', color='r')
traj, = plt.plot([],[], color='r', alpha=0.5)

def update(i):
    particle.set_data(x, y(x, t[i]))
    traj.set_data(x, y(x, t[i]))
    return particle, traj

plt.show()
plt.ioff()

ani = animation.FuncAnimation(fig, update, frames=range(100), interval=25)
ani.save('problem1.gif', writer=animation.PillowWriter(fps=30))
# TODO Get the mp4 saving to work
# ani.save("problem1.mp4")
# Out:
# <div id='8fdca423-0b67-4f1e-bfb9-8183f581ca3e'></div>

# %% [markdown]
# ## Problem 2
#
# The orbits for Mercury, Venus, Earth, and Mars are stored in the file `orbits.npz`. The file contains four NumPy arrays: `mercury`, `venus`, `earth`, and `mars`. The first column of each array contains the x-coordinates, the second column contains the y-coordinates, and the third column contians the z-coordinates, all relative to the Sun, and expressed in AU (astronomical units, the average distance between Earth and the Sun, approximately 150 million
# kilometers).
#
# Use `np.load('orbits.npz')` to load the data for the four planets' orbits. Create a 3D plot of the orbits, and compare your results with Figure 1.1.

# %%
# load data
orbits = np.load('orbits.npz')
mercury = orbits["mercury"]
venus = orbits["venus"]
earth = orbits["earth"]
mars = orbits["mars"]

# build plots
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.plot(mercury[:,0], mercury[:,1], mercury[:,2], label='Mercury', color='gray')
plt.plot(venus[:,0], venus[:,1], venus[:,2], label='Venus', color='orange')
plt.plot(earth[:,0], earth[:,1], earth[:,2], label='Earth', color='green')
plt.plot(mars[:,0], mars[:,1], mars[:,2], label='Mars', color='red')
plt.plot([0],[0],[0], color="yellow", marker="o", label="Sun")

# set plot parameters
ax.set_xlim(-1.1,1.1)
ax.set_ylim(-1.1,1.1)
ax.set_zlim(-1.1,1.1)
plt.title("Orbits of the Inner Planets")
plt.legend()
plt.show()
# Out:
# <div id='af6fbbb4-2aca-4ee9-b2bc-452d7ec49fb4'></div>

# %% [markdown]
# ## Problem 3
#
# Each row of the arrays in `orbits.npz` gives the position of the planets at a
# particular time. The arrays have 1400 points in time over a 700 day period (beginning on 2018-5-30). Create a 3D animation of the planet orbits. Display lines for the trajectories of the orbits and points for the current positions of the planets at each point in time. Your update() function will need to return a list of `Line3D` objects, one for each orbit trajectory and one for each planet position marker. Using `animation.save()`, save your animated plot, and embed you animated plot.

# %%
# build plots
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(-1.1,1.1)
ax.set_ylim(-1.1,1.1)
ax.set_zlim(-1.1,1.1)

# initialize particles and trajectories
part1, = plt.plot([],[],[], marker='o', color='gray')
traj1, = plt.plot([],[],[], marker='o', color='gray')
part2, = plt.plot([],[],[], marker='o', color='orange')
traj2, = plt.plot([],[],[], marker='o', color='orange')
part3, = plt.plot([],[],[], marker='o', color='green')
traj3, = plt.plot([],[],[], marker='o', color='green')
part4, = plt.plot([],[],[], marker='o', color='red')
traj4, = plt.plot([],[],[], marker='o', color='red')

#Update each particle and trajectory with the data in the planet
def update(i):
    part1.set_data(mercury[i,0],mercury[i,1])
    part1.set_3d_properties(mercury[i,2])
    traj1.set_data(mercury[:i+1,0],mercury[:i+1,1])
    traj1.set_3d_properties(mercury[:i+1,2])
    
    part2.set_data(venus[i,0],venus[i,1])
    part2.set_3d_properties(venus[i,2])
    traj2.set_data(venus[:i+1,0],venus[:i+1,1])
    traj2.set_3d_properties(venus[:i+1,2])
    
    part3.set_data(earth[i,0],earth[i,1])
    part3.set_3d_properties(earth[i,2])
    traj3.set_data(earth[:i+1,0],earth[:i+1,1])
    traj3.set_3d_properties(earth[:i+1,2])
    
    part4.set_data(mars[i,0],mars[i,1])
    part4.set_3d_properties(mars[i,2])
    traj4.set_data(mars[:i+1,0],mars[:i+1,1])
    traj4.set_3d_properties(mars[:i+1,2])
    
    return part1, traj1, part2, traj2, part3, traj3, part4, traj4


# Save the animation
# ani.save('planet_ani.mp4')
ani = animation.FuncAnimation(fig, update, frames=range(1400), interval=25)
ani.save('problem3.gif', writer=animation.PillowWriter(fps=30))
# Out:
# Exception ignored in: <bound method Comm.__del__ of <ipykernel.comm.comm.Comm object at 0x000002908ECA6C50>>
# Traceback (most recent call last):
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel\comm\comm.py", line 76, in __del__
#     self.close()
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel\comm\comm.py", line 116, in close
#     self.kernel.comm_manager.unregister_comm(self)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel\comm\manager.py", line 56, in unregister_comm
#     comm = self.comms.pop(comm.comm_id)
# KeyError: ('5d47617a65a34dabbc5d66c6cec5f6a8',)
# Exception ignored in: <bound method Comm.__del__ of <ipykernel.comm.comm.Comm object at 0x00000290B92B70B8>>
# Traceback (most recent call last):
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel\comm\comm.py", line 76, in __del__
#     self.close()
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel\comm\comm.py", line 116, in close
#     self.kernel.comm_manager.unregister_comm(self)
#   File "c:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel\comm\manager.py", line 56, in unregister_comm
#     comm = self.comms.pop(comm.comm_id)
# KeyError: ('48ddf7651c5d4f2ab22920e8406807d6',)

# %% [markdown]
# <video src="problem3.gif" controls>

# %% [markdown]
# ## Problem 4
#
# Make a surface plot of the bivariate normal density function given by:
#
# $$f(\mathbf{x}) = \frac{1}{\sqrt{det(2\pi\Sigma)}}exp[-\frac{1}{2}(\mathbf{x}-\mathbf{\mu})^{T}\Sigma^{-1}(\mathbf{x}-\mathbf{\mu})]$$
#
# Where $\mathbf{x} = [x,y]^T \in \mathbb{R}^2$, $\mathbf{\mu} = [0,0]^T$ is the mean vector, and: $$\Sigma = \begin{bmatrix} 1 & 3/5 \\ 3/5 & 2 \end{bmatrix}$$ is the covariance matrix.

# %%
# initialize gid
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# define the function
sigma = np.array([[1, 0.6], [0.6, 2]])
sig_inv = np.linalg.inv(sigma)
constant = 1 / np.sqrt(np.linalg.det(2 * np.pi * sigma))
mean = np.array([0, 0])
f = lambda x: constant * np.exp(-0.5 * np.dot(np.dot((x - mean), sig_inv), (x - mean)))

# build surface
Z = np.array([[f(np.array([X[i,j], Y[i,j]])) for j in range(Y.shape[0])] for i in range(X.shape[0])])

# set plot parameters
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(-4.1, 4.1)
ax.set_ylim(-4.1, 4.1)
ax.set_zlim(0, 0.13)

# plot surface
ax.plot_surface(X,Y,Z,cmap="magma")
plt.show()
print(Z.shape)
# TODO idk why this isn't showing
# Out:
# <div id='79b2eb05-8eb5-47d7-9312-8d5a78945e32'></div>
# <div id='00e9b93e-4a93-4af0-acb8-96a40c02a48f'></div>
# (100, 100)

# %% [markdown]
# ## Problem 5
#
# Use the data in vibration.npz to produce a surface animation of the solution
# to the wave equation for an elastic rectangular membrane. The file contains three NumPy arrays: `X`, `Y`, `Z`. `X` and `Y` are meshgrids of shape `(300,200)` corresponding to 300 points in
# the y-direction and 200 points in the x-direction, all corresponding to a 2x3 rectangle with one corner at the origin. `Z` is of shape `(150,300,200)`, giving the height of the vibrating membrane at each (x,y) point for 150 values of time. In the language of partial differential equations, this is the solution to the following intital/boundary value problem for the wave equation:
#
# $$u_{tt} = 6^2(u_{xx}+u_{yy})$$
# $$(x,y) \in [0,2]\times[0,3],t \in [0,5]$$
# $$u(t,0,y)=u(t,2,y)=u(t,x,0)=u(t,x,3) = 0$$
# $$u(0,x,y) = xy(2-x)(3-y)$$
#
# Load the data with `np.load('vibration.npz')`. Create a 3D surface animation of the vibrating membrane. Save the animation and embed it in the notebook.

# %%
# load data
vib = np.load("vibration.npz")
X = vib["X"]
Y = vib["Y"]
Z = vib["Z"]

# build figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0, 2)
ax.set_ylim(0, 3)
ax.set_zlim(0, 5)
ax.plot_surface(X, Y, Z[0], cmap="magma")

# update
def update(i):
    ax.clear()
    ax.set_xlim(0, 2)
    ax.set_ylim(0, 3)
    ax.set_zlim(0, 5)
    return ax.plot_surface(X, Y, Z[i], cmap="magma", alpha=0.5)

# save animation
ani = animation.FuncAnimation(fig, update, frames=range(149), interval=25)
ani.save("problem5.gif", writer=animation.PillowWriter(fps=30))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # load data
# ----> 2 vib = np.load("vibration.npz")
#       3 X = vib["X"]
#       4 Y = vib["Y"]
#
# File ~\anaconda3\lib\site-packages\numpy\lib\npyio.py:407, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     405     own_fid = False
#     406 else:
# --> 407     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     408     own_fid = True
#     410 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'vibration.npz'
